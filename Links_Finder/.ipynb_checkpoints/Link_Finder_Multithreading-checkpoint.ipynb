# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import re
from threading import Thread, Lock
import time
from urllib.parse import urlsplit

# %%
service = Service(executable_path=r'C:\Program Files\Google\Chrome\Application\chromedriver')
options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches",["ignore-certificate-errors"])
options.add_argument('--disable-gpu')
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.125 Safari/537.36")

# To make pages load faster by excluding some resources.
options.add_experimental_option( "prefs",{'profile.managed_default_content_settings.xhr': 2,
                                                 'profile.managed_default_content_settings.preflight': 2,
                                                 'profile.managed_default_content_settings.images': 2,
                                                'profile.managed_default_content_settings.font': 2,
                                                'profile.managed_default_content_settings.css': 2})

# %%
def enter_url():
    url = input('Enter URL: ')

    # URL validation
    if not url.startswith("https"):
        url = 'https://' + url
    elif not url.startswith("http"):
        url = 'http://' + url
    else:
        pass
    
    return url

# %%
url = enter_url()

def base_url(url):
    parts = urlsplit(url)
    base = '{0.netloc}'.format(parts)
    temp = base.split('.')
    remove_this = temp[0] + '.'
    base = base.replace(remove_this, '')
    
    return base

domain_url = base_url(url)
print(domain_url)
links_to_scrape = {}
links_to_scrape[url] = url
scraped_links = []
all_links = {}
lock = Lock()
# Out:
# Enter URL: https://thispointer.com/python-get-first-value-in-a-dictionary/
# com

# %%
print(type(links_to_scrape[url]))

# %%
def link_finder(url):
    driver = webdriver.Chrome(service=service, options=options)
    driver.get(url)

    # Give the required tag and/or class, etc.
    elems = driver.find_elements(by=By.TAG_NAME, value="a")
    global links_found
    links_found = []
    # Save the scraped links in list
    for elem in elems:
        link = elem.get_attribute("href")
        links_found.append(link)
        
    driver.quit()

# %%
def links_manager(links_found, scraped_links, links_to_scrape, url):
    
    for link in links_found:
        all_links[link] = 1
        link_base = base_url(link)
        if domain_url == link_base:
            if link in scraped_links:
                pass
            else:
                links_to_scrape[link] = link

# %%
link_finder(links_to_scrape[url])

# %%
print(links_found)

# %%
#link_finder(links_to_scrape[0])
#N = 1   # Number of browsers to spawn
thread_list = list()
link_finder(links_to_scrape[url])
# Start test
remaining_links = len(links_to_scrape)
i = 0
while remaining_links > 0:
    try:
        with lock:
            url = next(iter(links_to_scrape))
            scraped_links.append(url)
            del links_to_scrape[url]
    except:
        break
        
    t = Thread(name='Test {}'.format(i), target=link_finder, args=(url,))
    with lock:    
        links_manager(links_found, scraped_links, links_to_scrape, url)
    t.start()
    time.sleep(1)
    print(t.name + ' started!')
    thread_list.append(t)
    i += 1
    
# Wait for all threads to complete
for thread in thread_list:
    thread.join()

print('Test completed!')
# Out:
# Test 0 started!
# Test 1 started!
# Test 2 started!
# Test 3 started!
# Test 4 started!
# Test 5 started!
# Test 6 started!
# Test 7 started!
# Test 8 started!
# Test 9 started!
# Test 10 started!
# Test 11 started!
# Test 12 started!
# Test 13 started!
# Test 14 started!
# Test 15 started!
# Test 16 started!
# Test 17 started!
# Test 18 started!
# Test 19 started!
# Test 20 started!
# Test 21 started!
# Test 22 started!
# Test 23 started!
# Test 24 started!
# Test 25 started!
# Test 26 started!
# Test 27 started!
# Test 28 started!
# Test 29 started!
# Test 30 started!
# Test 31 started!
# Test 32 started!
# Test 33 started!
# Test 34 started!
# Test 35 started!
# Test 36 started!
# Test 37 started!
# Test 38 started!
# Test 39 started!
# Test 40 started!
# Test 41 started!
# Test 42 started!
# Test 43 started!
# Test 44 started!
# Exception in thread Test 4:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 6:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 2:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 3:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 10:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 14:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 11:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 19:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 28:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 27:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 36:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 44:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 5:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 8:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 17:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 26:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 25:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 30:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 32:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 33:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 37:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 39:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 40:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 35:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 31:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 23:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
# Exception in thread Test 38:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 21:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 16:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 42:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 41:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 34:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 43:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 24:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 15:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 20:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 7:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 12:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 1:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
# Exception in thread Test 9:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 29:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 18:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
# Exception in thread Test 22:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
# Exception in thread Test 13:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     self.run()
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 917, in run
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 917, in run
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 917, in run
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 917, in run
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     self.run()
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 917, in run
#     self.run()
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 917, in run
#     self.run()
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 917, in run
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     self.run()
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 917, in run
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\ramza\AppData\Local\Temp\ipykernel_19388\3666085978.py", line 3, in link_finder
#     self.run()
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 917, in run
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     self.run()
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 917, in run
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\ramza\AppData\Local\Temp\ipykernel_19388\3666085978.py", line 3, in link_finder
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\ramza\AppData\Local\Temp\ipykernel_19388\3666085978.py", line 3, in link_finder
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     self.run()
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 917, in run
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 917, in run
#     self.run()
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 917, in run
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...
#     return self._request(command_info[0], url, body=data)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py", line 311, in _request
#     response = self.command_executor.execute(driver_command, params)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py", line 290, in execute
#     return self._request(command_info[0], url, body=data)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py", line 311, in _request
#     response = self.execute(Command.NEW_SESSION, caps)["value"]
#   File "C:\Users\ramza\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 344, in execute
#     response = self._conn.request(method, url, body=body, headers=headers)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\request.py", line 78, in request
#     return self._request(command_info[0], url, body=data)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py", line 311, in _request
#     return self.request_encode_body(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\request.py", line 170, in request_encode_body
#     response = self._conn.request(method, url, body=body, headers=headers)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\request.py", line 78, in request
#     return self.urlopen(method, url, **extra_kw)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\poolmanager.py", line 376, in urlopen
#     response = self.command_executor.execute(driver_command, params)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py", line 290, in execute
#     response = self._conn.request(method, url, body=body, headers=headers)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\request.py", line 78, in request
#     return self.request_encode_body(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\request.py", line 170, in request_encode_body
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 787, in urlopen
#     return self._request(command_info[0], url, body=data)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py", line 311, in _request
#     return self.request_encode_body(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\request.py", line 170, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\poolmanager.py", line 376, in urlopen
#     response = self._conn.request(method, url, body=body, headers=headers)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\request.py", line 78, in request
#     retries = retries.increment(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\util\retry.py", line 550, in increment
#     return self.urlopen(method, url, **extra_kw)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\poolmanager.py", line 376, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 787, in urlopen
#     return self.request_encode_body(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\request.py", line 170, in request_encode_body
#     super().__init__(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 206, in __init__
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\packages\six.py", line 769, in reraise
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 787, in urlopen
#     retries = retries.increment(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\util\retry.py", line 550, in increment
#     return self.urlopen(method, url, **extra_kw)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\poolmanager.py", line 376, in urlopen
#     raise value.with_traceback(tb)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
#     retries = retries.increment(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\util\retry.py", line 550, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\packages\six.py", line 769, in reraise
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 787, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\packages\six.py", line 769, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
#     retries = retries.increment(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\util\retry.py", line 550, in increment
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\packages\six.py", line 769, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     raise value.with_traceback(tb)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     self.start_session(capabilities)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 291, in start_session
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#         version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
# version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     response = self.execute(Command.NEW_SESSION, caps)["value"]
#   File "C:\Users\ramza\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 344, in execute
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#     response = self.command_executor.execute(driver_command, params)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py", line 290, in execute
#     return self._request(command_info[0], url, body=data)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py", line 311, in _request
#     response = self._conn.request(method, url, body=body, headers=headers)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\request.py", line 78, in request
#     return self.request_encode_body(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\request.py", line 170, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\poolmanager.py", line 376, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 787, in urlopen
#     retries = retries.increment(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\util\retry.py", line 550, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\packages\six.py", line 769, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Exception in thread Test 103:
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\ramza\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\ramza\AppData\Local\Temp\ipykernel_19388\3666085978.py", line 2, in link_finder
#   File "C:\Users\ramza\anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py", line 49, in __init__
#     super().__init__(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\selenium\webdriver\chromium\webdriver.py", line 54, in __init__
#     super().__init__(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 206, in __init__
#     self.start_session(capabilities)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 291, in start_session
#     response = self.execute(Command.NEW_SESSION, caps)["value"]
#   File "C:\Users\ramza\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 344, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py", line 290, in execute
#     return self._request(command_info[0], url, body=data)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py", line 311, in _request
#     response = self._conn.request(method, url, body=body, headers=headers)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\request.py", line 78, in request
#     return self.request_encode_body(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\request.py", line 170, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\poolmanager.py", line 376, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 787, in urlopen
#     retries = retries.increment(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\util\retry.py", line 550, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\packages\six.py", line 769, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\ramza\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 1377, in getresponse
#     response.begin()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\ramza\anaconda3\lib\http\client.py", line 289, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Test completed!

# %%
print(len(all_links))
# Out:
# 117

# %%
print(all_links)
# Out:
# {'https://thispointer.com/python-get-first-value-in-a-dictionary/#content': 1, 'https://thispointer.com/python-programming/': 1, 'https://thispointer.com/data-analysis-in-python-using-pandas/': 1, 'https://thispointer.com/numpy-array-tutorials/': 1, 'https://thispointer.com/python-strings/': 1, 'https://thispointer.com/python-lists-tutorial/': 1, 'https://thispointer.com/python-dictionary/': 1, 'https://thispointer.com/tuples-in-python/': 1, 'https://thispointer.com/functions-in-python/': 1, 'https://thispointer.com/iterators-and-generators-in-python/': 1, 'https://thispointer.com/file-handling-in-python/': 1, 'https://thispointer.com/': 1, 'https://thispointer.com/category/javascript/': 1, 'https://thispointer.com/category/database/mysql/': 1, 'https://thispointer.com/category/linux/': 1, 'https://thispointer.com/c11-tutorial/': 1, 'https://thispointer.com/c-interview-questions/': 1, 'https://thispointer.com/stl-tutorials-and-interview-questions/': 1, 'https://thispointer.com/recommended-courses/': 1, 'https://thispointer.com/python-keywords-and-identifiers/': 1, 'https://thispointer.com/python-variables/': 1, 'https://thispointer.com/literals-in-python/': 1, 'https://thispointer.com/python-if-statement/': 1, 'https://thispointer.com/python-ifelse-statement/': 1, 'https://thispointer.com/python-ifelifelse-statement/': 1, 'https://thispointer.com/python-if-else-in-one-line-a-ternary-operator/': 1, 'https://thispointer.com/python-while-loop-explained-with-examples/': 1, 'https://thispointer.com/python-for-loop-explained-with-examples/': 1, 'https://thispointer.com/python-break-keyword-explained-with-examples/': 1, 'https://thispointer.com/python-continue-keyword-and-loops/': 1, 'https://thispointer.com/python-functions/#what-is-a-function-in-python': 1, 'https://thispointer.com/python-functions/#python-function-arguments-and-return-value': 1, 'https://thispointer.com/python-how-to-use-global-variables-in-a-function/': 1, 'https://thispointer.com/python-args-how-to-pass-multiple-arguments-to-function/': 1, 'https://thispointer.com/return-multiple-values-from-a-function-in-python/': 1, 'https://thispointer.com/what-is-a-list-in-python-and-why-we-need-it/': 1, 'https://thispointer.com/python-how-to-create-a-list-and-initialize-with-same-values/': 1, 'https://thispointer.com/python-how-to-check-if-an-item-exists-in-list-search-by-value-or-condition/': 1, 'https://thispointer.com/python-how-to-add-an-element-in-list-append-vs-extend/': 1, 'https://thispointer.com/python-how-to-insert-an-element-at-specific-index-in-list/': 1, 'https://thispointer.com/how-to-update-values-in-a-list-in-python/': 1, 'https://thispointer.com/python-how-to-iterate-over-a-list/': 1, 'https://thispointer.com/python-remove-elements-from-list-by-value/': 1, 'https://thispointer.com/python-remove-elements-from-list-by-index/': 1, 'https://thispointer.com/python-how-to-find-all-indexes-of-an-item-in-a-list/': 1, 'https://thispointer.com/python-how-to-sort-a-list-of-strings-list-sort-tutorial-examples/': 1, 'https://thispointer.com/python-how-to-merge-two-or-more-lists/': 1, 'https://thispointer.com/python-get-number-of-elements-in-a-list-lists-of-lists-or-nested-list/': 1, 'https://thispointer.com/python-3-ways-to-check-if-there-are-duplicates-in-a-list/': 1, 'https://thispointer.com/python-how-to-access-characters-in-string-by-index/': 1, 'https://thispointer.com/python-check-if-a-string-contains-a-sub-string-find-its-index-case-insensitive/': 1, 'https://thispointer.com/python-how-to-iterate-over-the-characters-in-string/': 1, 'https://thispointer.com/python-find-occurrence-count-all-indices-of-a-sub-string-in-another-string-including-overlapping-sub-strings/': 1, 'https://thispointer.com/python-how-to-compare-strings-ignore-case-regex-is-vs-operator/': 1, 'https://thispointer.com/python-how-to-remove-characters-from-a-string-by-index/': 1, 'https://thispointer.com/replace-instances-of-a-character-in-a-string-in-python/': 1, 'https://thispointer.com/how-to-s ...

# %%
print(scraped_links)

# %%
print(links_to_scrape)

# %%
print(len(links_to_scrape))
print(len(scraped_links))
# Out:
# 0
# 115
